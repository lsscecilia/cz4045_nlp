# %% [markdown]
# # POS Tagging

# %% [markdown]
# ## Download libraries

# %%
# !pip install pandas
# !pip install --user -U nltk
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# Out:
# Requirement already satisfied: pandas in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: nltk in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from nltk) (0.17.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from nltk) (2021.10.8)
# Requirement already satisfied: tqdm in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from nltk) (4.61.2)
# Requirement already satisfied: pip in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (21.1.3)
# Collecting pip
#   Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (52.0.0.post20210125)
# Collecting setuptools
#   Using cached setuptools-58.3.0-py3-none-any.whl (946 kB)
# Requirement already satisfied: wheel in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (0.36.2)
# Collecting wheel
#   Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 52.0.0.post20210125
#     Uninstalling setuptools-52.0.0.post20210125:
#       Successfully uninstalled setuptools-52.0.0.post20210125
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# Successfully installed pip-21.3.1 setuptools-58.3.0 wheel-0.37.0
# Requirement already satisfied: spacy in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (3.1.2)
# Collecting spacy
#   Downloading spacy-3.1.3-cp39-cp39-macosx_10_9_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 5.7 MB/s
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: jinja2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (3.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (4.61.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (21.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (2.4.1)
# Requirement already satisfied: setuptools in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (58.3.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: pathy>=0.3.5 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (1.20.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy) (8.0.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: catalogue, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.5
#     Uninstalling catalogue-2.0.5:
#       Successfully uninstalled catalogue-2.0.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.1.2
#     Uninstalling spacy-3.1.2:
#       Successfully uninstalled spacy-3.1.2
# Successfully installed catalogue-2.0.6 spacy-3.1.3

# %%
# pandas
import pandas as pd

# random
import random

# NLTK packages
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tag import pos_tag as pos_tagger
from nltk import UnigramTagger
from nltk.tag import BigramTagger

# spaCy lib
import spacy
# !python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.61.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: setuptools in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: jinja2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cecilialee/miniconda3/lib/python3.9/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#import the json-file and put it in a dataframe
df = pd.read_json('../data/reviewSelected100.json', lines=True, encoding = "ISO-8859-1")

#dataframe
df
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
#        stars  useful  funny  cool  \
# 0          5       0      0     0
# 1          4       0      0     0
# 2          5       2      1     3
# 3          3       0      0     0
# 4          1      11      0     3
# ...      ...     ...    ...   ...
# 15295      1       2      0     0
# 15296      5       0      0     0
# 15297      1       0      1     0
# 15298      5       0      0     0
# 15299      5       0      0     0
#
#                                                     text                date
# 0      We had my Mother's Birthday Party here on 10/2... 2016-11-09 20:07:25
# 1      Good Korean grill near Eaton Centre. The marin... 2015-12-05 05:06:43
# 2      Was recommended to try this place by few peopl... 2014-10-11 05:16:15
# 3      Ambience: Would not expect something this nice... 2016-07-25 03:45:26
# 4      Absolutely the WORST pool company that I have ... 2016-04-11 18:49:11
# ...                                                  ...                 ...
# 15295  This was the worst experience ever. So much so... 2014-07-12 21:58:15
# 15296  We come here every time we hit Vegas! A giant ... 2018-11-10 21:38:49
# 15297  As locals we used  to the this place when it w... 2018-10-13 22:11:22
# 15298  The food was delicious. We were seated in 15 m... 2015-02-15 08:43:46
# 15299  Wonderful spot (the patio) and OH SO EXCELLENT... 2018-10-06 19:00:13
#
# [15300 rows x 9 columns]

# %% [markdown]
# ### Clean text data

# %%
#select all the text
text = df['text'].astype('str') 

#join all the text into one string
all_text = ''.join(map(str, text))

# %%
#separating the string into sentences
sentences = sent_tokenize(all_text)

#sentences

# %% [markdown]
# #### Select 5 random sentences

# %%
#select 5 random sentences
random_5_sentences = random.choices(sentences, k=5)

pd.options.display.max_colwidth = 300
pd.DataFrame(random_5_sentences, columns=['sentence'])
# Out:
#                                                                                                       sentence
# 0                                                    No judgement here, as I like to lick my plates clean too!
# 1                                                                                              It was a blast.
# 2                    The night manager started shouting at me and even told me that my room was not his issue.
# 3                                                                                     calls were extra charge.
# 4  We dropped in during show time and since the box office was closed, we decided to sneak into the main show.

# %% [markdown]
# #### NLTK

# %%
nltk_pos_tag_li = []
for i in range(len(random_5_sentences)):
    tagged_sentence = nltk.pos_tag(word_tokenize(random_5_sentences[i]))
    nltk_pos_tag_li.append(tagged_sentence)

# %% [markdown]
# #### spaCy

# %%
spacy_pos_tag_li = []
for i in range(len(random_5_sentences)):
    sentence_to_tag = nlp(random_5_sentences[i])
    
    sentence_pos_tag_li = []
    for token in sentence_to_tag:
        sentence_pos_tag_li.append(tuple([token.text, token.pos_]))
    
    spacy_pos_tag_li.append(sentence_pos_tag_li)

# %% [markdown]
# ### Results

# %%
from IPython.core import display as ICD

for i in range(len(random_5_sentences)):
    table_nltk_pos_tag = pd.DataFrame(nltk_pos_tag_li[i], columns=['word', 'POS_Tag_NLTK'])
    table_spacy_pos_tag = pd.DataFrame(spacy_pos_tag_li[i], columns=['word', 'POS_Tag_spaCy'])
    print("-------------- Sentence "+ str(i+1) + " --------------")
    combined_table = table_nltk_pos_tag.merge(table_spacy_pos_tag, left_index=True, right_index=True, how='left')
    ICD.display(combined_table.drop(combined_table.columns[2], axis=1))
# Out:
# -------------- Sentence 1 --------------
#        word_x POS_Tag_NLTK POS_Tag_spaCy
# 0          No           DT           DET
# 1   judgement           NN          NOUN
# 2        here           RB           ADV
# 3           ,            ,         PUNCT
# 4          as           IN           ADP
# 5           I          PRP          PRON
# 6        like          VBP          VERB
# 7          to           TO          PART
# 8        lick           VB          VERB
# 9          my         PRP$          PRON
# 10     plates          NNS          NOUN
# 11      clean          VBP           ADJ
# 12        too           RB           ADV
# 13          !            .         PUNCT
# -------------- Sentence 2 --------------
#   word_x POS_Tag_NLTK POS_Tag_spaCy
# 0     It          PRP          PRON
# 1    was          VBD           AUX
# 2      a           DT           DET
# 3  blast           NN          NOUN
# 4      .            .         PUNCT
# -------------- Sentence 3 --------------
#       word_x POS_Tag_NLTK POS_Tag_spaCy
# 0        The           DT           DET
# 1      night           NN          NOUN
# 2    manager           NN          NOUN
# 3    started          VBD          VERB
# 4   shouting          VBG          VERB
# 5         at           IN           ADP
# 6         me          PRP          PRON
# 7        and           CC         CCONJ
# 8       even           RB           ADV
# 9       told          VBD          VERB
# 10        me          PRP          PRON
# 11      that           IN         SCONJ
# 12        my         PRP$          PRON
# 13      room           NN          NOUN
# 14       was          VBD           AUX
# 15       not           RB          PART
# 16       his         PRP$          PRON
# 17     issue           NN          NOUN
# 18         .            .         PUNCT
# -------------- Sentence 4 --------------
#    word_x POS_Tag_NLTK POS_Tag_spaCy
# 0   calls          NNS          NOUN
# 1    were          VBD           AUX
# 2   extra           JJ           ADJ
# 3  charge           NN          NOUN
# 4       .            .         PUNCT
# -------------- Sentence 5 --------------
#      word_x POS_Tag_NLTK POS_Tag_spaCy
# 0        We          PRP          PRON
# 1   dropped          VBD          VERB
# 2        in           IN           ADP
# 3    during           IN           ADP
# 4      show           NN          NOUN
# 5      time           NN          NOUN
# 6       and           CC         CCONJ
# 7     since           IN         SCONJ
# 8       the           DT           DET
# 9       box           NN         PROPN
# 10   office           NN          NOUN
# 11      was          VBD          VERB
# 12   closed          VBN           ADJ
# 13        ,            ,         PUNCT
# 14       we          PRP          PRON
# 15  decided          VBD          VERB
# 16       to           TO          PART
# 17    sneak           VB          VERB
# 18     into           IN           ADP
# 19      the           DT           DET
# 20     main           JJ           ADJ
# 21     show           NN          NOUN
# 22        .            .         PUNCT

# %% [markdown]
# ## Research: Unigram vs Bigram

# %% [markdown]
# #### Split the remaining unselected data to be used as training data

# %%
#Split the data into train and test
for i in range(len(random_5_sentences)):
    sentences.remove(random_5_sentences[i]) #Remove the 5 random chosen sentences for testing; rest of the sentences will be used for training

# %% [markdown]
# ### Unigram and Bigram Toolkit

# %%
#Tag each sentences and add to new list
def tagged_sentences(sentences):
    list_sentences = []
    for i in range(len(sentences)):
        tagged_sentence_i = nltk.pos_tag(word_tokenize(sentences[i]))
        list_sentences.append(tagged_sentence_i)
    
    return list_sentences

# %%
#Training Unigram and storing results
def unigram_result(sentences_train, sentences_test, tagged_sentences_test):
    #Training the NgramTagger
    unigram_tagger = nltk.UnigramTagger(sentences_train)
    
    #Storing results of test
    list_results = []
    for i in range(len(sentences_test)):
        result_sentence_i = unigram_tagger.tag(word_tokenize(sentences_test[i]))
        list_results.append(result_sentence_i)
        
    #evaluate results
    accuracy = unigram_tagger.evaluate(tagged_sentences_test)
    
    return list_results, accuracy

# %%
sentences_train = tagged_sentences(sentences)
tagged_sentences_test = tagged_sentences(random_5_sentences)

# %% [markdown]
# ##### train bigram manually

# %%
#Training the BigramTagger
bigram_tagger = nltk.BigramTagger(sentences_train)

#Storing results of test
list_bigram = []
for i in range(len(random_5_sentences)):
    result_sentence_i = bigram_tagger.tag(word_tokenize(random_5_sentences[i]))
    list_bigram.append(result_sentence_i)

#evaluate results
acc_bigram = bigram_tagger.evaluate(tagged_sentences_test)

# %%
#Results of unigram
list_unigram, acc_unigram = unigram_result(sentences_train, random_5_sentences, tagged_sentences_test)
#list_bigram, acc_bigram = bigram_result(sentences_train, random_5_sentences, tagged_sentences_test)

# %% [markdown]
# ## Results

# %% [markdown]
# ### Accuracy

# %%
print ('accuracy of unigram:', acc_unigram)
print ('accuracy of bigram :', acc_bigram)
# Out:
# accuracy of unigram: 0.9696969696969697
# accuracy of bigram : 0.5

# %%
from IPython.core import display as ICD

for i in range(len(random_5_sentences)):
    table_unigram = pd.DataFrame(list_unigram[i], columns=['word', 'POS_Tag_Unigram'])
    table_bigram = pd.DataFrame(list_bigram[i], columns=['word', 'POS_Tag_Bigram'])
    print("-------------- Sentence "+ str(i+1) + " --------------")
    combined_table = table_unigram.merge(table_bigram, left_index=True, right_index=True, how='left')
    ICD.display(combined_table.drop(combined_table.columns[2], axis=1))
# Out:
# -------------- Sentence 1 --------------
#        word_x POS_Tag_Unigram POS_Tag_Bigram
# 0          No              DT             DT
# 1   judgement              NN           None
# 2        here              RB           None
# 3           ,               ,           None
# 4          as              IN           None
# 5           I             PRP           None
# 6        like              IN           None
# 7          to              TO           None
# 8        lick              VB           None
# 9          my            PRP$           None
# 10     plates             NNS           None
# 11      clean              JJ           None
# 12        too              RB           None
# 13          !               .           None
# -------------- Sentence 2 --------------
#   word_x POS_Tag_Unigram POS_Tag_Bigram
# 0     It             PRP            PRP
# 1    was             VBD            VBD
# 2      a              DT             DT
# 3  blast              NN             NN
# 4      .               .              .
# -------------- Sentence 3 --------------
#       word_x POS_Tag_Unigram POS_Tag_Bigram
# 0        The              DT             DT
# 1      night              NN             NN
# 2    manager              NN             NN
# 3    started             VBD            VBD
# 4   shouting             VBG           None
# 5         at              IN           None
# 6         me             PRP           None
# 7        and              CC           None
# 8       even              RB           None
# 9       told             VBD           None
# 10        me             PRP           None
# 11      that              IN           None
# 12        my            PRP$           None
# 13      room              NN           None
# 14       was             VBD           None
# 15       not              RB           None
# 16       his            PRP$           None
# 17     issue              NN           None
# 18         .               .           None
# -------------- Sentence 4 --------------
#    word_x POS_Tag_Unigram POS_Tag_Bigram
# 0   calls             NNS           None
# 1    were             VBD           None
# 2   extra              JJ           None
# 3  charge              NN           None
# 4       .               .           None
# -------------- Sentence 5 --------------
#      word_x POS_Tag_Unigram POS_Tag_Bigram
# 0        We             PRP            PRP
# 1   dropped             VBD            VBD
# 2        in              IN             IN
# 3    during              IN             IN
# 4      show              NN             NN
# 5      time              NN             NN
# 6       and              CC             CC
# 7     since              IN             IN
# 8       the              DT             DT
# 9       box              NN             NN
# 10   office              NN             NN
# 11      was             VBD            VBD
# 12   closed             VBN            VBN
# 13        ,               ,              ,
# 14       we             PRP            PRP
# 15  decided             VBD            VBD
# 16       to              TO             TO
# 17    sneak              VB             VB
# 18     into              IN             IN
# 19      the              DT             DT
# 20     main              JJ             JJ
# 21     show              NN             NN
# 22        .               .              .

# %% [markdown]
# ### Combining Taggers

# %% [markdown]
# #### Find the most commonly used tagger

# %%
tags = []
for li in range(len(sentences_train)):
    for li_item in range(len(sentences_train[li])):
        tags.append(sentences_train[li][li_item][1])

# %%
nltk.FreqDist(tags).max()
# Out:
# 'NN'

# %%
default_tagger = nltk.DefaultTagger('NN')

# %% [markdown]
# #### Adding Backoff tagger

# %%
t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(sentences_train, backoff=t0)
t2 = nltk.BigramTagger(sentences_train, backoff=t1)

# %%
#Result of combining taggers
list_combine = []
for i in range(len(random_5_sentences)):
    result_sentence_i = t2.tag(word_tokenize(random_5_sentences[i]))
    list_combine.append(result_sentence_i)

#evaluate results
acc_combine = t2.evaluate(tagged_sentences_test)

# %% [markdown]
# ### Accuracy

# %%
print ('accuracy of unigram  :', acc_unigram)
print ('accuracy of bigram   :', acc_bigram)
print ('accuracy of combining:', acc_combine)
# Out:
# accuracy of unigram  : 0.9696969696969697
# accuracy of bigram   : 0.5
# accuracy of combining: 1.0

# %%
from IPython.core import display as ICD

for i in range(len(random_5_sentences)):
    table_unigram = pd.DataFrame(list_unigram[i], columns=['word', 'POS_Tag_Unigram'])
    table_combine = pd.DataFrame(list_combine[i], columns=['word', 'POS_Tag_Combine'])
    print("-------------- Sentence "+ str(i+1) + " --------------")
    merged_table = table_unigram.merge(table_combine, left_index=True, right_index=True, how='left')
    ICD.display(merged_table.drop(merged_table.columns[2], axis=1))
# Out:
# -------------- Sentence 1 --------------
#        word_x POS_Tag_Unigram POS_Tag_Combine
# 0          No              DT              DT
# 1   judgement              NN              NN
# 2        here              RB              RB
# 3           ,               ,               ,
# 4          as              IN              IN
# 5           I             PRP             PRP
# 6        like              IN             VBP
# 7          to              TO              TO
# 8        lick              VB              VB
# 9          my            PRP$            PRP$
# 10     plates             NNS             NNS
# 11      clean              JJ             VBP
# 12        too              RB              RB
# 13          !               .               .
# -------------- Sentence 2 --------------
#   word_x POS_Tag_Unigram POS_Tag_Combine
# 0     It             PRP             PRP
# 1    was             VBD             VBD
# 2      a              DT              DT
# 3  blast              NN              NN
# 4      .               .               .
# -------------- Sentence 3 --------------
#       word_x POS_Tag_Unigram POS_Tag_Combine
# 0        The              DT              DT
# 1      night              NN              NN
# 2    manager              NN              NN
# 3    started             VBD             VBD
# 4   shouting             VBG             VBG
# 5         at              IN              IN
# 6         me             PRP             PRP
# 7        and              CC              CC
# 8       even              RB              RB
# 9       told             VBD             VBD
# 10        me             PRP             PRP
# 11      that              IN              IN
# 12        my            PRP$            PRP$
# 13      room              NN              NN
# 14       was             VBD             VBD
# 15       not              RB              RB
# 16       his            PRP$            PRP$
# 17     issue              NN              NN
# 18         .               .               .
# -------------- Sentence 4 --------------
#    word_x POS_Tag_Unigram POS_Tag_Combine
# 0   calls             NNS             NNS
# 1    were             VBD             VBD
# 2   extra              JJ              JJ
# 3  charge              NN              NN
# 4       .               .               .
# -------------- Sentence 5 --------------
#      word_x POS_Tag_Unigram POS_Tag_Combine
# 0        We             PRP             PRP
# 1   dropped             VBD             VBD
# 2        in              IN              IN
# 3    during              IN              IN
# 4      show              NN              NN
# 5      time              NN              NN
# 6       and              CC              CC
# 7     since              IN              IN
# 8       the              DT              DT
# 9       box              NN              NN
# 10   office              NN              NN
# 11      was             VBD             VBD
# 12   closed             VBN             VBN
# 13        ,               ,               ,
# 14       we             PRP             PRP
# 15  decided             VBD             VBD
# 16       to              TO              TO
# 17    sneak              VB              VB
# 18     into              IN              IN
# 19      the              DT              DT
# 20     main              JJ              JJ
# 21     show              NN              NN
# 22        .               .               .
